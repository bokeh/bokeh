# %%
import bokeh
from bokeh.util import structure as st
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-6c2beb596b39> in <module>
#       1 import bokeh
# ----> 2 from bokeh.util import structure as st
#       3 from bokeh.plotting import figure
#       4 from bokeh.io import output_notebook, show
#
# ~/GitHub/bokeh/bokeh/util/structure.py in <module>
#      22 from bokeh.models import ColumnDataSource, HoverTool, LabelSet, Range1d
#      23 from bokeh.models.glyphs import Circle, MultiLine
# ---> 24 from bokeh.plotting import figure, from_networkx
#      25 from bokeh.util.string import format_docstring
#      26
#
# ~/GitHub/bokeh/bokeh/plotting/__init__.py in <module>
#      70 from ..models.layouts import Row, Column; Row, Column
#      71
# ---> 72 from ..io import curdoc; curdoc
#      73 from ..io import output_file; output_file
#      74 from ..io import output_notebook; output_notebook
#
# ~/GitHub/bokeh/bokeh/io/__init__.py in <module>
#      21 # Bokeh imports
#      22 from .doc import curdoc
# ---> 23 from .export import export_png, export_svgs
#      24 from .notebook import install_jupyter_hooks, install_notebook_hook, push_notebook
#      25 from .output import output_file, output_notebook, reset_output
#
# ~/GitHub/bokeh/bokeh/io/export.py in <module>
#      36 from ..resources import INLINE, Resources
#      37 from .util import default_filename
# ---> 38 from .webdriver import WebDriver, webdriver_control
#      39
#      40 #-----------------------------------------------------------------------------
#
# ~/GitHub/bokeh/bokeh/io/webdriver.py in <module>
#     161 #-----------------------------------------------------------------------------
#     162
# --> 163 webdriver_control = _WebdriverState()
#     164
#     165 atexit.register(lambda: webdriver_control.reset())
#
# ~/GitHub/bokeh/bokeh/io/webdriver.py in __init__(self, reuse, kind)
#     113                 self.kind = "firefox"
#     114             else:
# --> 115                 raise RuntimeError("Neither firefox/geckodriver nor chromium-browser/chromedriver are available on system PATH. " \
#     116                                    "You can install the former with 'conda install -c conda-forge firefox geckodriver'.")
#     117
#
# RuntimeError: Neither firefox/geckodriver nor chromium-browser/chromedriver are available on system PATH. You can install the former with 'conda install -c conda-forge firefox geckodriver'.

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#     <p style="background-color: #f2d7dc;">Warning: Requesting CDN BokehJS version '2.0.0dev6' from Bokeh development version '2.0.0dev6-17-gad6dbf076'. This configuration is unsupported and may not work!</p>

# %%
import numpy as np
X = np.linspace(-1,1,100)
Y = X + np.random.normal(size=X.shape)
f=figure(width=400,height=400)
_=f.line(x=X,y=Y,color='blue',line_width=3,alpha=.5)
_=f.line(x=X,y=X,color='red',line_width=3)

# %%
show(f)
# Out:
#   <div class="bk-root" id="e92a9a76-ae8a-427d-875b-9e83091b1357" data-root-id="21574"></div>

# %%
show(st.draw_model(f))
# Out:
#   <div class="bk-root" id="a0ceb69f-d9b8-46fd-b5cd-2965bb53e971" data-root-id="31455"></div>

# %%
print(bokeh.__version__)
# Out:
# 2.0.0dev6-18-gdf14b2802-dirty
